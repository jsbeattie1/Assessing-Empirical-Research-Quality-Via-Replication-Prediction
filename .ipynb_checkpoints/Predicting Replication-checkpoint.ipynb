# %% [markdown]
# ## Introduction
#
# **The goal of this project is to predict the results when empirical research is replicated. Put more broadly, the idea is to assess the quality/dependability of empirical research results, allowing for more well-informed conclusions concerning the scale of purported effects or patterns.**
#
# **Replication, i.e. repeating a study that has already been carried out, is a crucial part of the scientific process. It aids in separating genuine effects from statistical artifacts and in determining how large the genuine effects actually are. In recent years, it has become clear that due to various factors (publication and grant-making practices, conventional statistical methodologies, etc.), published research is less dependable - less replicable - than might be hoped. This is often referred to as a "replication crisis", and one response has been the organization of several "replication projects", in which resources are devoted to replicating a collection of studies in a given field. These have so far been carried out for research in psychology, experimental economics, social sciences, and experimental philosophy. The data used for this project is taken from a paper entitled "Probabilistic forecasting of replication studies" (https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0231416), which collected and standardized the results from these 4 replication projects.**

# %% [markdown]
# ## Loading & Preparing the Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('replications_ma_subset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Study                     143 non-null    object
#  1   r_OS                      143 non-null    float64
#  2   r_RS                      143 non-null    float64
#  3   FZ_OS                     143 non-null    float64
#  4   FZ_RS                     143 non-null    float64
#  5   FZ_se_OS                  143 non-null    float64
#  6   FZ_se_RS                  143 non-null    float64
#  7   pval_RS                   143 non-null    float64
#  8   N_OS                      143 non-null    int64
#  9   N_RS                      143 non-null    int64
#  10  pval_OS                   143 non-null    float64
#  11  Project                   143 non-null    object
#  12  Survey_Belief_Premarket   39 non-null     float64
# ...

# %% [markdown]
# **The data consists of 143 studies in total, with the main statistical result in each case converted to a correlation coefficient (r).**
#
# **Three of the columns have a large number of null values. This is because those features were only considered in one or two of the replication projects - the goal was to assess how well professional researchers could predict replication results. In any case, these are not predictive features, so they are not needed for the current project.**

# %%
df = df.drop(['Survey_Belief_Premarket','Survey_Belief_Postmarket','Market_Belief','pval_RS_significant'],axis=1)

# %%
df = df.rename({'r_OS':'r_orig','r_RS':'r_rep','FZ_OS':'fz_orig','FZ_RS':'fz_rep','FZ_se_OS':'fz_se_orig',
               'FZ_se_RS':'fz_se_rep','N_OS':'n_orig','N_RS':'n_rep'},axis=1)

# %%
df['p_orig'] = df['pval_OS']
df['p_rep'] = df['pval_RS']

# %%
category = df['Project']
df = df.drop(['pval_RS','pval_OS','Project'],axis=1)
df.insert(1,'Category',category)

# %% [markdown]
# **For the target of prediction, I will use the mean (weighted by sample size) of the effect, i.e. correlation coefficient, in the original study and the effect in the corresponding replication study. This is a very conservative approach. It gives both studies equal legitimacy, treating them as if they were each random estimates of the actual effect. In actuality, the original studies have consistently higher r values - most likely due to a combination of publication bias and other biases creeping in during the execution of the research - which means it would make sense to weight the result of the replication study more heavily than the original result. But intead of attempting to determine the ideal weighting balance, I will simply use the conservative approach, which can be thought of as an upper bound on the post-replication estimated effect.**
#
# **In order to calculate a weighted average of two correlation coefficients, it is necessary to convert the r scores to Fisher's Z scores, which are additive, and then convert back. Those calculations are carried out immediately below.**

# %%
fz_combined = ((df['fz_orig']*df['n_orig'])+(df['fz_rep']*df['n_rep']))/(df['n_orig']+df['n_rep'])
df['r_combined'] = (np.exp(2*fz_combined)-1)/(np.exp(2*fz_combined)+1)

# %%
import scipy.stats as stats

# %%
t = df['r_combined']*np.sqrt((df['n_orig']+df['n_rep']-2)/(1-df['r_combined']**2))
df['p_combined'] = stats.t.sf(abs(t),df=(df['n_orig']+df['n_rep']-2))

# %%
df['p<0.05'] = np.where(df['p_combined']<0.05,'Yes','No')
df['p<0.05'].value_counts()
# Out:
# Yes    115
# No      28
# Name: p<0.05, dtype: int64

# %%
df.head()
# Out:
#                                                Study    Category    r_orig  \
# 0                                          A Roelofs  Psychology  0.594605
# 1                                AL Morris, ML Still  Psychology  0.611120
# 2  B Liefooghe, P Barrouillet, A Vandierendonck, ...  Psychology  0.424980
# 3                       BC Storm, EL Bjork, RA Bjork  Psychology  0.228740
# 4                         C Mitchell, S Nash, G Hall  Psychology  0.461301
#
#       r_rep   fz_orig    fz_rep  fz_se_orig  fz_se_rep  n_orig  n_rep  \
# 0  0.148340  0.684760  0.149443    0.288675   0.192450      24     29
# 1  0.229605  0.710707  0.233772    0.213201   0.213201      24     24
# 2 -0.215244  0.453754 -0.218663    0.208514   0.182574      25     32
# 3 -0.006108  0.232859 -0.006108    0.072739   0.061199     240    270
# 4  0.134812  0.498962  0.135638    0.182574   0.147442      32     48
#
#      p_orig     p_rep  r_combined  p_combined p<0.05
# ...

# %% [markdown]
# ## Data Visualization
#
# **The first two visualizations below show that the correlation coefficients in the original studies are consistently higher than those in the replication studies. First, the distributions of the two sets:**

# %%
plt.figure(figsize=(10,5))
ax = sns.kdeplot(df[['r_orig','r_rep']])
ax1 = sns.rugplot(df[['r_orig','r_rep']])
plt.title('Correlation Coefficients in Original Studies vs. Replication Studies')
plt.xlabel('Correlation Coefficient')
plt.legend(labels=['Replication Studies','Original Studies'])

# %% [markdown]
# **Next, a histogram showing the distribution of differences for each study-replication pair. If the two studies were equally random estimates of the actual effect, this distribution would be expected to be symmetric around the red line at 0 (i.e. the replication results would be equally likely to be above or below the original results). Clearly, though, the original studies have systematically higher values.**

# %%
plt.figure(figsize=(9,5))
sns.histplot(df['r_orig']-df['r_rep'])
plt.axvline(0,color='red',lw=2)
plt.title('Difference in Correlation Coefficient: Original Study - Replication Study')
plt.xlabel('Difference in Correlation Coefficient (Original - Replication)')
plt.xticks([-1,-0.75,-0.5,-0.25,0,.25,.5,.75,1])
# Out:
# ([<matplotlib.axis.XTick at 0x7f331be36610>,
# ...
#  [Text(-1.0, 0, '−1.00'),
#   Text(-0.75, 0, '−0.75'),
#   Text(-0.5, 0, '−0.50'),
#   Text(-0.25, 0, '−0.25'),
#   Text(0.0, 0, '0.00'),
#   Text(0.25, 0, '0.25'),
#   Text(0.5, 0, '0.50'),
#   Text(0.75, 0, '0.75'),
#   Text(1.0, 0, '1.00')])

# %% [markdown]
# **Next, a box plot that shows a similar relationship, but this time between the original studies and the weighted average (to be used as target for prediction):**

# %%
plt.figure(figsize=(10,5))
ax = sns.boxplot(data=df[['r_orig','r_combined']],orient='h')
plt.title('Original Correlation Coefficients vs. Post-Replication Weighted Average')
ax.set_xlabel('Correlation Coefficient')
ax.set_yticklabels(['Original Study','Weighted Average\n(Original + Replication)'])
# Out:
# [Text(0, 0, 'Original Study'),
#  Text(0, 1, 'Weighted Average\n(Original + Replication)')]

# %% [markdown]
# **The P-value is an oft-used measure of a study's results, and one way of assessing replications would be to see whether the P-value of (a) the replication study or (b) the weighted average of the two studies is statistically significant (and in the same direction as the original). A key lesson of the replication crisis, though, is that *too much* attention and emphasis is generally put on P-values, which are of inherently limited value. For example, as this project shows, even when replication results remain statistically significant, it is often the case that the *scale* of the effect is smaller than was suggested by the original study, and that is important information to capture.**
#
# **In any case, though P-values won't be used further in this project, the bar graph below shows that (a) the results of replication studies are statistically significant only around half the time, but (b) the average result of the two studies is statistically significant nearly as often as in the original studies. (As noted above, a better estimate of the average result would fall somewhere between these two extremes).**

# %%
items = ['Original Studies','Weighted Averages','Replication Studies']
values = [len(df[df['p_orig']<0.05])/len(df),len(df[df['p_combined']<0.05])/len(df),len(df[df['p_rep']<0.05])/len(df)]
percentages = [round(v*100,1) for v in values]
percentages
# Out:
# [92.3, 80.4, 49.7]

# %%
plt.figure()
ax = sns.barplot(x=items,y=percentages)
plt.title('Percentage of Statistically Significant Results (P<0.05)')
ax.set_yticks([0,20,40,60,80,100])
# ax.set_yticklabels(['0%','20%','40%','60%','80%','100%'])
ax.set_yticklabels([])
ax.set_ylabel('Percentage')
for i in range(3):
    plt.text(i,percentages[i]+2,'{:.1f}%'.format(percentages[i]),color='black',ha='center')

# %% [markdown]
# ## Model Building

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.inspection import permutation_importance
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.metrics import mean_squared_error

# %%
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,[1,2,3,6,8]], df['r_combined'], random_state=22,
                                                   stratify = df['Category'])

# %% [markdown]
# **We have already seen that original study results are a flawed guide to post-replication results. To establish a baseline for improvement, we'll measure the error that would come from using the original study results as the sole basis for predicting the post-replication average.**

# %%
mean_squared_error(df['r_orig'],df['r_combined'])
# Out:
# 0.02754096164701973

# %% [markdown]
# **As an initial, very simple model, we can find the average difference between the results (correlation coefficient r) of the original studies and their corresponding replications, and subtract half of that from the original results. This yields a mean squared error of 0.0185, as seen below. This is already a substantial improvement on the baseline.**
#
# **Column 3 (r values from the replication studies) has been left in the dataframe temporarily to allow for the calculation of this simple model (and to generate a new input feature that will be included later). It is not itself an input feature, however.**

# %%
# Calculate overall mean difference between original r and replication r
X_train['r_orig'].mean()-X_train['r_rep'].mean()
# Out:
# 0.185987867557486

# %%
simple_predictions = X_test['r_orig']-0.5*(X_train['r_orig'].mean()-X_train['r_rep'].mean())
baseline_error = mean_squared_error(y_test,simple_predictions)
baseline_error
# Out:
# 0.01853206346948298

# %% [markdown]
# **A slightly more complicated model involves performing this calculation separately for each of the 4 categories of research (psychology, experimental economics, social sciences, and experimental philosophy). This does not yield any improvement.**

# %%
# Calculate mean difference for each category separately
X_train_psych = X_train[X_train['Category']=='Psychology']
psych_diff = X_train_psych['r_orig'].mean()-X_train_psych['r_rep'].mean()

X_train_econ = X_train[X_train['Category']=='Experimental Economics']
econ_diff = X_train_econ['r_orig'].mean()-X_train_econ['r_rep'].mean()

X_train_soc = X_train[X_train['Category']=='Social Sciences']
soc_diff = X_train_soc['r_orig'].mean()-X_train_soc['r_rep'].mean()

X_train_phil = X_train[X_train['Category']=='Experimental Philosophy']
phil_diff = X_train_phil['r_orig'].mean()-X_train_phil['r_rep'].mean()

# %%
preds_by_category = []
for i in range(0,len(X_test)):
    if X_test.iloc[i]['Category']=='Psychology':
        preds_by_category.append(X_test.iloc[i]['r_orig']-0.5*psych_diff)
    if X_test.iloc[i]['Category']=='Experimental Economics':
        preds_by_category.append(X_test.iloc[i]['r_orig']-0.5*econ_diff)
    if X_test.iloc[i]['Category']=='Social Sciences':
        preds_by_category.append(X_test.iloc[i]['r_orig']-0.5*soc_diff)
    if X_test.iloc[i]['Category']=='Experimental Philosophy':
        preds_by_category.append(X_test.iloc[i]['r_orig']-0.5*phil_diff)
        
mean_squared_error(y_test,preds_by_category)
# Out:
# 0.020440933304677337

# %% [markdown]
# **Given that the overall mean difference performed better than discipline-specific mean differences, the former will be added to the dataframe as an input feature.**

# %%
mean_diff = X_train['r_orig'].mean()-X_train['r_rep'].mean()
X_train['mean_diff'] = X_train['r_orig'] - X_train['r_rep'] # puts placeholder value in each row
X_train['mean_diff'] = np.where(X_train['mean_diff']>-2,mean_diff,0) # replaces placeholder values with mean difference

# %%
X_test['mean_diff'] = X_test['r_orig'] - X_test['r_rep']
X_test['mean_diff'] = np.where(X_test['mean_diff']>-2,mean_diff,0)

# %% [markdown]
# **At this point, we can begin training and cross-validating regression models. This, too, will be done in two stages: one in which the study category is simply left as one of the features, and one in which the data is split up and separate regressions are run for each category.**
#
# **The only inputs will be features of the original studies, plus the mean difference (calculated from the training set).**

# %%
X_train = X_train.drop('r_rep',axis=1)
X_test = X_test.drop('r_rep',axis=1)

# %%
# Preparation for column transformation: split into discrete features (for one-hot-encoding) 
# and numeric features (for polynomial features)
discrete = ['Category']
numeric = list(X_train.columns[1:])

transformer = ColumnTransformer([('ohe',OneHotEncoder(handle_unknown='ignore'),discrete),('pf',PolynomialFeatures(include_bias=False),numeric),
                                ('ss',StandardScaler(),numeric)])

# %%
linreg = LinearRegression()
ridge = Ridge(max_iter=5000)
lasso = Lasso(max_iter=5000)
models = [linreg,ridge,lasso]

linreg_params = {'transformer__pf__degree':[1,2,3,4,5,6]}
ridge_params = {'transformer__pf__degree':[1,2,3,4,5,6],'model__alpha':[0.01,0.1,1.0,10.0,100.0,1000.0]}
lasso_params = {'transformer__pf__degree':[1,2,3,4,5,6],'model__alpha':[0.01,0.1,1.0,10.0,100.0,1000.0]}
params = [linreg_params,ridge_params,lasso_params]

# %%
lr_pipe = Pipeline([('transformer',transformer),('model',linreg)])
lr_grid = GridSearchCV(estimator=lr_pipe,param_grid=linreg_params,scoring='neg_mean_squared_error').fit(X_train,y_train)
lr_mse = mean_squared_error(y_test,lr_grid.predict(X_test))
lr_mse
# Out:
# 0.01907699521882691

# %%
ridge_pipe = Pipeline([('transformer',transformer),('model',ridge)])
ridge_grid = GridSearchCV(estimator=ridge_pipe,param_grid=ridge_params,scoring='neg_mean_squared_error').fit(X_train,y_train)
ridge_mse = mean_squared_error(y_test,ridge_grid.predict(X_test))
ridge_mse
# Out:
# 0.018696549526522804

# %%
lasso_pipe = Pipeline([('transformer',transformer),('model',lasso)])
lasso_grid = GridSearchCV(estimator=lasso_pipe,param_grid=lasso_params,scoring='neg_mean_squared_error').fit(X_train,y_train)
lasso_mse = mean_squared_error(y_test,lasso_grid.predict(X_test))
lasso_mse
# Out:
# 0.017020749443551943

# %%
lasso_grid.best_params_
# Out:
# {'model__alpha': 0.01, 'transformer__pf__degree': 1}

# %% [markdown]
# **The best-performing model - and the only one to improve on the simple model above - is a Lasso model with alpha = 0.01.**
#
# **This process will now be repeated, but with discipline-specific mean differences included rather than the overall mean difference.**

# %%
# Put discipline-specific mean differences in appropriate rows of 'mean_diff' column
X_train['mean_diff'].mask(X_train['Category']=='Psychology',float(psych_diff),inplace=True)
X_train['mean_diff'].mask(X_train['Category']=='Experimental Economics',float(econ_diff),inplace=True)
X_train['mean_diff'].mask(X_train['Category']=='Social Sciences',float(soc_diff),inplace=True)
X_train['mean_diff'].mask(X_train['Category']=='Experimental Philosophy',float(phil_diff),inplace=True)

X_test['mean_diff'].mask(X_test['Category']=='Psychology',float(psych_diff),inplace=True)
X_test['mean_diff'].mask(X_test['Category']=='Experimental Economics',float(econ_diff),inplace=True)
X_test['mean_diff'].mask(X_test['Category']=='Social Sciences',float(soc_diff),inplace=True)
X_test['mean_diff'].mask(X_test['Category']=='Experimental Philosophy',float(phil_diff),inplace=True)

# %%
lr_pipe1 = Pipeline([('transformer',transformer),('model',linreg)])
lr_grid1 = GridSearchCV(estimator=lr_pipe1,param_grid=linreg_params,scoring='neg_mean_squared_error').fit(X_train,y_train)
lr_mse1 = mean_squared_error(y_test,lr_grid1.predict(X_test))
lr_mse1
# Out:
# 0.01907699521882702

# %%
ridge_pipe1 = Pipeline([('transformer',transformer),('model',ridge)])
ridge_grid1 = GridSearchCV(estimator=ridge_pipe1,param_grid=ridge_params,scoring='neg_mean_squared_error').fit(X_train,y_train)
ridge_mse1 = mean_squared_error(y_test,ridge_grid1.predict(X_test))
ridge_mse1
# Out:
# 0.01903483113705535

# %%
lasso_pipe1 = Pipeline([('transformer',transformer),('model',lasso)])
lasso_grid1 = GridSearchCV(estimator=lasso_pipe1,param_grid=lasso_params,scoring='neg_mean_squared_error').fit(X_train,y_train)
lasso_mse1 = mean_squared_error(y_test,lasso_grid1.predict(X_test))
lasso_mse1
# Out:
# 0.018758202846097697

# %% [markdown]
# **As before, this yields no improvement.**
#
# **Another tweak: after going back to using the overall mean difference, the Category column is removed to avoid the need for one-hot encoding.**

# %%
# Put the overall mean difference back in all rows of the 'mean_diff' column (all rows are > -2)
X_train['mean_diff'] = np.where(X_train['mean_diff']>-2,mean_diff,0)
X_test['mean_diff'] = np.where(X_test['mean_diff']>-2,mean_diff,0)

# %%
# Make copy of dataframes with no Category column
X_train_nc = X_train.drop('Category',axis=1)
X_test_nc = X_test.drop('Category',axis=1)

# %%
# New column transformer for all numeric columns (no more need for one-hot-encoding)
numeric = list(X_train_nc.columns)
transformer2 = ColumnTransformer([('pf',PolynomialFeatures(include_bias=False),numeric),('ss',StandardScaler(),numeric)])

# %%
lr_pipe2 = Pipeline([('transformer',transformer2),('model',linreg)])
lr_grid2 = GridSearchCV(estimator=lr_pipe2,param_grid=linreg_params,scoring='neg_mean_squared_error').fit(X_train_nc,y_train)
lr_mse2 = mean_squared_error(y_test,lr_grid2.predict(X_test_nc))
lr_mse2
# Out:
# 0.016568472141239573

# %%
ridge_pipe2 = Pipeline([('transformer',transformer2),('model',ridge)])
ridge_grid2 = GridSearchCV(estimator=ridge_pipe2,param_grid=ridge_params,scoring='neg_mean_squared_error').fit(X_train_nc,y_train)
ridge_mse2 = mean_squared_error(y_test,ridge_grid2.predict(X_test_nc))
ridge_mse2
# Out:
# 0.017105063129821924

# %%
lasso_pipe2 = Pipeline([('transformer',transformer2),('model',lasso)])
lasso_grid2 = GridSearchCV(estimator=lasso_pipe2,param_grid=lasso_params,scoring='neg_mean_squared_error').fit(X_train_nc,y_train)
lasso_mse2 = mean_squared_error(y_test,lasso_grid2.predict(X_test_nc))
lasso_mse2
# Out:
# 0.017475912988779443

# %%
lr_grid2.best_params_
# Out:
# {'transformer__pf__degree': 1}

# %% [markdown]
# **Removing the Category column has led to a slightly improved model. The best performer is now Linear Regression, with a mean squared error of 0.0166.**
#
# **The final thing to try is training separate regression models for each discipline.**

# %%
i_psych = []
i_econ = []
i_soc = []
i_phil = []
for i in range(0,len(X_train)):
    if X_train.iloc[i]['Category']=='Psychology':
        i_psych.append(i)
    if X_train.iloc[i]['Category']=='Experimental Economics':
        i_econ.append(i)
    if X_train.iloc[i]['Category']=='Social Sciences':
        i_soc.append(i)
    if X_train.iloc[i]['Category']=='Experimental Philosophy':
        i_phil.append(i)

# %%
X_train_psych = X_train.iloc[i_psych].drop('Category',axis=1)
y_train_psych = y_train.iloc[i_psych]
X_train_econ = X_train.iloc[i_econ].drop('Category',axis=1)
y_train_econ = y_train.iloc[i_econ]
X_train_soc = X_train.iloc[i_soc].drop('Category',axis=1)
y_train_soc = y_train.iloc[i_soc]
X_train_phil = X_train.iloc[i_phil].drop('Category',axis=1)
y_train_phil = y_train.iloc[i_phil]

# %%
lr_psych = linreg.fit(X_train_psych,y_train_psych)
lr_econ = linreg.fit(X_train_econ,y_train_econ)
lr_soc = linreg.fit(X_train_soc,y_train_soc)
lr_phil = linreg.fit(X_train_phil,y_train_phil)

# %%
[X_test.iloc[1,1:].values]
# Out:
# [array([0.00464002, 0.0422200330920749, 684, 0.185987867557486],
#        dtype=object)]

# %%
preds_by_category = []
for i in range(0,len(X_test)):
    if X_test.iloc[i]['Category']=='Psychology':
        preds_by_category.append(lr_psych.predict([X_test.iloc[i,1:].values]))
    if X_test.iloc[i]['Category']=='Experimental Economics':
        preds_by_category.append(lr_econ.predict([X_test.iloc[i,1:].values]))
    if X_test.iloc[i]['Category']=='Social Sciences':
        preds_by_category.append(lr_soc.predict([X_test.iloc[i,1:].values]))
    if X_test.iloc[i]['Category']=='Experimental Philosophy':
        preds_by_category.append(lr_phil.predict([X_test.iloc[i,1:].values]))

# %%
lr_mse_separate = mean_squared_error(y_test,preds_by_category)
lr_mse_separate
# Out:
# 0.02099363674135903

# %% [markdown]
# **Once again, this yields no improvement. (Splitting by discipline is probably unhelpful because a couple of the categories have quite small sample sizes - it would be interesting to see what would happen if all of them were as large as the Psychology set).**

# %% [markdown]
# ## Results Visualization

# %%
df_test = pd.concat([X_test,y_test],axis=1)

# %%
df_test['Predictions'] = lr_grid2.predict(X_test_nc)
df_test['Simple Predictions'] = simple_predictions
df_test = df_test.sort_values(by=['r_orig'],ascending=False)

# %%
plt.figure(figsize=(12,5))
sns.lineplot(list(df_test['r_orig']),label='Original Study')
sns.lineplot(list(df_test['r_combined']),label='Post-Replication Weighted Average')
sns.lineplot(list(df_test['Predictions']),label='Regression Model Predictions')
sns.lineplot(list(df_test['Simple Predictions']),label='Simple Model Predictions')
plt.title('Replication Predictions (Test Set)')
plt.xlabel('Studies Sorted by r (High to Low)')
plt.ylabel('Correlation Coefficient (r)')
# Out:
# Text(0, 0.5, 'Correlation Coefficient (r)')

# %%
full_mean_diff = df['r_orig'].mean()-df['r_rep'].mean()
df['mean_diff'] = df['r_orig'] - df['r_rep'] # puts placeholder value in each row
df['mean_diff'] = np.where(df['mean_diff']>-2,full_mean_diff,0) # replaces placeholder values with mean difference

# %%
df_plot = df.iloc[:,[2,6,8,12,15]]

# %%
df_plot['Predictions'] = lr_grid2.predict(df_plot)
full_simple_predictions = df['r_orig'] - 0.5*full_mean_diff
df_plot['Simple Predictions'] = full_simple_predictions
df_plot = df_plot.sort_values(by=['r_orig'],ascending=False)

# %%
plt.figure(figsize=(12,5))
sns.lineplot(list(df_plot['r_orig']),label='Original Study')
sns.lineplot(list(df_plot['r_combined']),label='Post-Replication Weighted Average')
sns.lineplot(list(df_plot['Predictions']),label='Regression Model Predictions')
sns.lineplot(list(df_plot['Simple Predictions']),label='Simple Model Predictions')
plt.title('Replication Predictions (Full Dataset)')
plt.xlabel('Studies Sorted by r (High to Low)')
plt.ylabel('Correlation Coefficient (r)')
# Out:
# Text(0, 0.5, 'Correlation Coefficient (r)')

# %%
plt.figure(figsize=(12,5))
sns.lineplot(list(df_plot['r_orig'][30:71]),label='Original Study')
sns.lineplot(list(df_plot['r_combined'][30:71]),label='Post-Replication Weighted Average')
sns.lineplot(list(df_plot['Predictions'][30:71]),label='Regression Model Predictions')
sns.lineplot(list(df_plot['Simple Predictions'][30:71]),label='Simple Model Predictions')
plt.title('Replication Predictions (Full Dataset, Zoomed In, Studies 30-70)')
plt.xlabel('Studies Sorted by r (High to Low)')
plt.ylabel('Correlation Coefficient (r)')
x = list(range(0,41))
xticklabels = list(range(30,71))
plt.xticks(x,xticklabels)
# Out:
# ([<matplotlib.axis.XTick at 0x7f3314406390>,
# ...
#  [Text(0, 0, '30'),
#   Text(1, 0, '31'),
#   Text(2, 0, '32'),
#   Text(3, 0, '33'),
#   Text(4, 0, '34'),
#   Text(5, 0, '35'),
#   Text(6, 0, '36'),
#   Text(7, 0, '37'),
#   Text(8, 0, '38'),
#   Text(9, 0, '39'),
#   Text(10, 0, '40'),
#   Text(11, 0, '41'),
#   Text(12, 0, '42'),
#   Text(13, 0, '43'),
#   Text(14, 0, '44'),
#   Text(15, 0, '45'),
#   Text(16, 0, '46'),
#   Text(17, 0, '47'),
#   Text(18, 0, '48'),
#   Text(19, 0, '49'),
#   Text(20, 0, '50'),
#   Text(21, 0, '51'),
#   Text(22, 0, '52'),
#   Text(23, 0, '53'),
#   Text(24, 0, '54'),
#   Text(25, 0, '55'),
#   Text(26, 0, '56'),
#   Text(27, 0, '57'),
#   Text(28, 0, '58'),
#   Text(29, 0, '59'),
#   Text(30, 0, '60'),
#   Text(31, 0, '61'),
#   Text(32, 0, '62'),
#   Text(33, 0, '63'),
#   Text(34, 0, '64'),
#   Text(35, 0, '65'),
#   Text(36, 0, '66'),
#   Text(37, 0, '67'),
#   Text(38, 0, '68'),
#   Text(39, 0, '69'),
#   Text(40, 0, '70')])
